# %%
import pandas as pd
import numpy as np

# %%
from sklearn import datasets
import pandas as pd

# %% [markdown]
# ## Iris Flower
# ![](http://5047-presscdn.pagely.netdna-cdn.com/wp-content/uploads/2015/04/iris_petal_sepal.png)

# %%
iris = datasets.load_iris()
x = pd.DataFrame(iris['data'], columns=iris['feature_names'])
print("target_names: "+str(iris['target_names']))
y = pd.DataFrame(iris['target'], columns=['target_names'])
data = pd.concat([x,y], axis=1)
data.head(3)
# Out:
# target_names: ['setosa' 'versicolor' 'virginica']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target_names
# 0             0
# 1             0
# 2             0

# %%
import numpy as np

# %%
list1 = [1,2,3,4,5]
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
np.array(list1)
# Out:
# array([1, 2, 3, 4, 5])

# %%
list2 = ["1", 2,3.,4,5]
list2
# Out:
# ['1', 2, 3.0, 4, 5]

# %%
np.array(list2)
# Out:
# array(['1', '2', '3.0', '4', '5'],
#       dtype='<U3')

# %% [markdown]
# ## Pandas Series

# %%
s1 = pd.Series([1, 3, 6, np.nan, 44, 1])
print(type(s1))
s1
# Out:
# <class 'pandas.core.series.Series'>
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    44.0
# 5     1.0
# dtype: float64

# %%
s2 = pd.Series([1,2,3], index=['a', 'b', 'c'])
print(type(s2))
s2
# Out:
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(type(data.head(5)['sepal length (cm)']))
data.head(5)['sepal length (cm)']
# Out:
# <class 'pandas.core.series.Series'>
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64

# %% [markdown]
# ## Pandas DataFrame

# %%
df = pd.DataFrame(np.random.randn(6,4),columns=['a','b','c','d'])
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           a         b         c         d
# 0 -0.495886  0.349915  0.134219 -0.032376
# 1 -0.979078  0.630289 -0.027901 -0.039128
# 2  1.311583  0.851632  1.292174 -0.190673
# 3  0.265065  1.337182 -0.322276  0.536818
# 4 -0.480431  0.876064  1.347095 -0.361583
# 5 -0.352931  0.910087  1.163870  1.779835

# %% [markdown]
# ## DataFrame Basic information（DataFrame基本資訊）

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# target_names         150 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 5.9 KB

# %%
data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)  target_names
# count        150.000000    150.000000
# mean           1.198667      1.000000
# std            0.763161      0.819232
# min            0.100000      0.000000
# 25%            0.300000      0.000000
# 50%            1.300000      1.000000
# 75%            1.800000      2.000000
# max            2.500000      2.000000

# %%
data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target_names'],
#       dtype='object')

# %%
data.sort_values(by='sepal length (cm)').head(5)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 13                4.3               3.0                1.1               0.1
# 42                4.4               3.2                1.3               0.2
# 38                4.4               3.0                1.3               0.2
# 8                 4.4               2.9                1.4               0.2
# 41                4.5               2.3                1.3               0.3
#
#     target_names
# 13             0
# 42             0
# 38             0
# 8              0
# 41             0

# %% [markdown]
# ## Data Selection(資料選取)

# %%
data['sepal length (cm)'].head(5)
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64

# %%
data[['sepal length (cm)','sepal width (cm)']].head(5)
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %%
data[0:5]['sepal length (cm)']
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64

# %%
data[5:10][['sepal length (cm)','sepal width (cm)']]
# Out:
#    sepal length (cm)  sepal width (cm)
# 5                5.4               3.9
# 6                4.6               3.4
# 7                5.0               3.4
# 8                4.4               2.9
# 9                4.9               3.1

# %%
data.loc[5:10, ['sepal length (cm)','sepal width (cm)']]
# Out:
#     sepal length (cm)  sepal width (cm)
# 5                 5.4               3.9
# 6                 4.6               3.4
# 7                 5.0               3.4
# 8                 4.4               2.9
# 9                 4.9               3.1
# 10                5.4               3.7

# %% [markdown]
# ## Data Selection with condition(資料篩選)

# %%
data[data['sepal length (cm)'] > 7]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 102                7.1               3.0                5.9               2.1
# 105                7.6               3.0                6.6               2.1
# 107                7.3               2.9                6.3               1.8
# 109                7.2               3.6                6.1               2.5
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 122                7.7               2.8                6.7               2.0
# 125                7.2               3.2                6.0               1.8
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 135                7.7               3.0                6.1               2.3
#
#      target_names
# 102             2
# 105             2
# 107             2
# 109             2
# 117             2
# 118             2
# 122             2
# 125             2
# 129             2
# 130             2
# 131             2
# 135             2

# %%
data[data['target_names'].isin([1,2])]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# 55                 5.7               2.8                4.5               1.3
# 56                 6.3               3.3                4.7               1.6
# 57                 4.9               2.4                3.3               1.0
# 58                 6.6               2.9                4.6               1.3
# 59                 5.2               2.7                3.9               1.4
# 60                 5.0               2.0                3.5               1.0
# 61                 5.9               3.0                4.2               1.5
# 62                 6.0               2.2                4.0               1.0
# 63                 6.1               2.9                4.7               1.4
# 64                 5.6               2.9                3.6               1.3
# 65                 6.7               3.1                4.4               1.4
# 66                 5.6               3.0                4.5               1.5
# 67                 5.8               2.7                4.1               1.0
# 68                 6.2               2.2                4.5               1.5
# 69                 5.6               2.5                3.9               1.1
# 70                 5.9               3.2                4.8               1.8
# 71                 6.1               2.8                4.0               1.3
# 72                 6.3               2.5                4.9               1.5
# 73                 6.1               2.8                4.7               1.2
# 74                 6.4               2.9                4.3               1.3
# 75                 6.6               3.0                4.4               1.4
# 76                 6.8               2.8                4.8               1.4
# 77                 6.7               3.0                5.0               1.7
# 78                 6.0               2.9                4.5               1.5
# 79                 5.7               2.6                3.5               1.0
# ..                 ...               ...                ...               ...
# 120                6.9               3.2                5.7               2.3
# 121                5.6               2.8                4.9               2.0
# 122                7.7               2.8                6.7               2.0
# 123                6.3               2.7                4.9               1.8
# 124                6.7               3.3                5.7               2.1
# 125                7.2               3.2                6.0               1.8
# 126                6.2               2.8                4.8               1.8
# 127                6.1               3.0                4.9               1.8
# 128                6.4               2.8                5.6               2.1
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target_names
# 50              1
# 51              1
# 52              1
# 53              1
# 54              1
# 55              1
# 56              1
# 57              1
# 58              1
# 59              1
# 60              1
# 61              1
# 62              1
# 63              1
# 64              1
# 65              1
# 66              1
# 67              1
# 68              1
# 69              1
# 70              1
# 71              1
# 72              1
# 73              1
# 74              1
# 75              1
# 76              1
# 77              1
# 78              1
# 79              1
# ..            ...
# 120             2
# 121             2
# 122             2
# 123             2
# 124             2
# 125             2
# 126             2
# 127             2
# 128             2
# 129             2
# 130             2
# 131             2
# 132             2
# 133             2
# 134             2
# 135             2
# 136             2
# 137             2
# 138             2
# 139             2
# 140             2
# 141             2
# 142             2
# 143             2
# 144             2
# 145             2
# 146             2
# 147             2
# 148             2
# 149             2
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Data Grouping(資料分群)

# %%
data.groupby(by='target_names').sum()
# Out:
#               sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target_names
# 0                         250.3             170.9               73.2
# 1                         296.8             138.5              213.0
# 2                         329.4             148.7              277.6
#
#               petal width (cm)
# target_names
# 0                         12.2
# 1                         66.3
# 2                        101.3

# %%
data.groupby(by='target_names').mean()
# Out:
#               sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target_names
# 0                         5.006             3.418              1.464
# 1                         5.936             2.770              4.260
# 2                         6.588             2.974              5.552
#
#               petal width (cm)
# target_names
# 0                        0.244
# 1                        1.326
# 2                        2.026
